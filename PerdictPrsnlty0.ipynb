# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrj086/New-Projects/blob/main/PerdictPrsnlty0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import joblib

print("Loading data...")

data = pd.read_csv("personality_data.csv")

print("Preparing features...")

X = data[["social_hours", "friends_count", "party_frequency"]]
y = data["personality"]

print("Training model...")

model = RandomForestClassifier(random_state=42)
model.fit(X, y)

joblib.dump(model, "personality_model.pkl")

print("Model trained successfully.", flush=True)
# Out:
# Loading data...
# Preparing features...
# Training model...
# Model trained successfully.

# %%
import joblib

model = joblib.load("personality_model.pkl")

social_hours = float(input("Hours spent socially per week: "))
friends_count = int(input("Number of close friends: "))
party_frequency = int(input("Party frequency per month: "))

prediction = model.predict([[social_hours, friends_count, party_frequency]])

print("Predicted personality:", prediction[0])
# Out:
# Hours spent socially per week: 10
# Number of close friends: 2
# Party frequency per month: 1
# Predicted personality: Introvert
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
